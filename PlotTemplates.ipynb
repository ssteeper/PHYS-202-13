# %% [markdown]
# Publication ready plot template
# ==
# Simple graphing template for matplotlib functions and data plots
# -

# %% [markdown]
# Line Plots
# -

# %%
y = arange(-5, 5, .01)
E = cosh(y)              
p = sinh(y)

# %%
#plotting
plot(y, E, label = "E", c='blue', lw=2)
plot(y, p, label = "p", c='red', lw=2)

#label and grid
xlabel('y')
ylabel('Energy, momentum')
grid = True

#axis manipulation
ax = gca()
ax.spines['right'].set_color('none')
ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_color('none')
ax.spines['top'].set_position('zero')
ax.spines['left'].set_smart_bounds(True)
ax.spines['bottom'].set_smart_bounds(True)
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

show()

# %% [markdown]
# Subplots
# -

# %%
subplot(211)
plot(y, E, label = "E", c='blue', lw=2)
ylabel('Energy, momentum')

subplot(212)
plot(y, p, label = "p", c='red', lw=2)
xlabel('y')
ylabel('Energy, momentum')

show()

# %% [markdown]
# Scatterplots
# -

# %%
n = 200
X = random.normal(0,1,n)
Y = random.normal(0,1,n)
plot(X, Y, 'd', c='red')
xlabel('x')
ylabel('y')
title('scatter plot')

#uncomment for axes centered at zero
#ax = gca()
#ax.spines['right'].set_color('none')
#ax.spines['left'].set_position('zero')
#ax.spines['bottom'].set_color('none')
#ax.spines['top'].set_position('zero')
#ax.spines['left'].set_smart_bounds(True)
#ax.spines['bottom'].set_smart_bounds(True)
#ax.xaxis.set_ticks_position('bottom')
#ax.yaxis.set_ticks_position('left')

show()
