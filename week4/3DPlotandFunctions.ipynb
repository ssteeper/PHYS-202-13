# %% [markdown]
# 3D Plotting and Functions
# =

# %% [markdown]
# Electric Dipole Potential
# -
#
# $
# V(x,y) = \dfrac{kq}{\sqrt{x^2+(y-d)^2}}-\dfrac{kq}{\sqrt{x^2+(y+d)^2}}
# $

# %%
dx, dy = .06,.06
x = arange(-2., 2., dx)
y = arange(-2., 2., dy)
#print x.ndim
#print len(x)

X,Y = meshgrid(x,y)
#print X.ndim
#print Y.shape

k=1.; q=1.; d=1.
V=(k*q)/(((X**2)+(Y-d)**2))**(1/2.)-(k*q)/((X**2)+(Y+d)**2)**(1/2.)

from mpl_toolkits.mplot3d import Axes3D
fig = figure()
ax = fig.gca(projection='3d')
p = ax.plot_surface(X, Y, V, rstride=1, cstride=1, lw=0, cmap=cm.prism)
cb = fig.colorbar(p, shrink=.5)

# %%
#Represent 3D data by contours
#levels = array([8, 4, 2, 1, .5, .25, 0, -.25, -.5, -1, -2, -4, -8])
levels = linspace(8.03, -8.012, num=100)

contour(X,Y,V,levels,cmap=cm.flag)
show()

# %% [markdown]
# EX 1:
# =
# Make a 3-D plot of the function
#
# $
# G(x,y) = e^{(-x^2-y^2)}
# $
#
# over the range -6 < $(x,y)$ < 6 using 51 bins in $x$ and 51 bins in $y$.

# %%
dx, dy = 12/51.0,12/51.0
xmin, xmax = -6., 6.
ymin, ymax = -6., 6.
x = arange(xmin, xmax, dx)
y = arange(ymin, ymax, dy)
nbinsx = (2*xmax)/dx
nbinsy = (2*ymax)/dy

X,Y = meshgrid(x,y)
G = e**(-X**2-Y**2)

from mpl_toolkits.mplot3d import Axes3D
fig = figure()
ax = fig.gca(projection='3d')
p = ax.plot_surface(X, Y, G, rstride=1, cstride=1, lw=0, cmap=cm.prism)
cb = fig.colorbar(p, shrink=.5)

# %%
levels = linspace(-3.01, 3.01012, num=100)
contour(X,Y,G,levels,cmap=cm.flag)
show()

# %% [markdown]
# EX 2
# =

# %%
k = 8.98755178e9  #N * m/C**2
q = 10**(-9)      #coulombs
d = 2             #meters
x = arange(-4., 4., dx)
y = arange(-4., 4., dy)
X,Y = meshgrid(x,y)
V = (k*q)/sqrt((X**2)+(Y-d)**2) + (k*q)/sqrt((X**2)+(Y+d)**2) - (k*q)/sqrt((X-d)**2+(Y**2)) - (k*q)/sqrt(((X+d)**2)+(Y**2))

fig = figure()
ax = fig.gca(projection='3d')
p = ax.plot_surface(X, Y, V, rstride=1, cstride=1, lw=0, cmap=cm.prism)
cb = fig.colorbar(p, shrink=.5)

# %%
levels = linspace(-2.1, 2.3, num=1000)
contour(X,Y,V,levels,cmap=cm.flag)
show()

# %% [markdown]
# EX 3
# =
# (a)
# -
# The first function should be named pointPotential(). It should take as arguments the point or points in space where you want to know the potential, the size (and sign) of the charge q and the position of the charge in the plane, and return the electric potential due to that charge.

# %%
def pointPotential(x, y, q, posx, posy):
    """Computes electric potential from charge q at posx, posy and returns the potential at x,y"""
    k = 8.98755178e9 
    return (k*q)/sqrt((x-posx)**2 + (y-posy)**2)

# %%
x=1.
y=1.
V11 = pointPotential(x,y,1e-9,0.,0.)
print V11
# Out:
# 6.3551588099

# %%
x,y = meshgrid(arange(-2.,2.,.06),arange(-2.,2.,.06))
Vxy= pointPotential(x,y,1e-9,0.,0.)
print Vxy
# Out:
# [[ 3.1775794   3.22559494  3.27428945 ...,  3.30710904  3.25798497
#    3.20951244]
#  [ 3.22559494  3.27585506  3.32689792 ...,  3.36134185  3.30979898
#    3.25901295]
#  [ 3.27428945  3.32689792  3.38040362 ...,  3.41655454  3.36247082
#    3.30926047]
#  ...,
#  [ 3.30710904  3.36134185  3.41655454 ...,  3.45389066  3.3980434
#    3.3431539 ]
#  [ 3.25798497  3.30979898  3.36247082 ...,  3.3980434   3.34482043
#    3.29243067]
#  [ 3.20951244  3.25901295  3.30926047 ...,  3.3431539   3.29243067
#    3.24242796]]

# %% [markdown]
# (b)
# -

# %% [markdown]
# Create another function dipolePotential(), that takes as arguments the point or points in space where you want to know the potential, the size of the charges q, and the separation distance d between the charges. This function should call the pointPotential function you created in part(a) and return the electric potential due to the dipole. For simplicity, let the two charges lie along the x-axis with their midpoint at the origin.

# %%
def dipolePotential(x,y,q,d):
    """Returns Potential for a dipole system"""
    return pointPotential(x,y,q,-d,0) + pointPotential(x,y,q,d,0)

# %% [markdown]
# (c)
# -
# Finally, use these newly created funcitons to remake the 3D plots of the dipole and quadrupole that we did in class.

# %%
x,y, = meshgrid(arange(-4.,4.,.06),arange(-4.,4.,.06))
q = 1e-9
d = 2

V = dipolePotential(x,y,q,d)

fig = figure()
ax = fig.gca(projection='3d')
p = ax.plot_surface(x, y, V, rstride=1, cstride=1, lw=0, cmap=cm.prism)
cb = fig.colorbar(p, shrink=.5)

# %%
def quadrupolePotential(x,y,q,d):
    return pointPotential(x,y,q,-d,0) + pointPotential(x,y,q,d,0) + pointPotential(x,y,q,0,-d) + pointPotential(x,y,q,0,d)

V = quadrupolePotential(x,y,q,d)

fig = figure()
ax = fig.gca(projection='3d')
p = ax.plot_surface(x, y, V, rstride=1, cstride=1, lw=0, cmap=cm.prism)
cb = fig.colorbar(p, shrink=.5)
