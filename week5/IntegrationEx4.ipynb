# %% [markdown]
# Numerical Integration, Exercises 4
# ==

# %% [markdown]
# 1.
# =
# Consider the integral
# \begin{equation}
# E(x) = \int_0^xe^{-t^2}dt
# \end{equation}

# %% [markdown]
# (a)
# -
# Write code to calculate
# E
# (
# x
# ) for values of
# x
# from 0 to 3 in steps of 0.1. Choose for
# yourself what method you will use for performing the integral and a suitable number of
# slices.

# %%
import scipy.integrate as integrate
x = arange(0, 3, .1)
f = lambda t: e**(-t**2)
y = f(x)
E = np.zeros(30)
for i in range(30):
    E[i] = integrate.trapz(y[:i], x[:i], dx=.1)

# %%
plot(x, E)
xlabel('x', fontsize = 16)
ylabel('E', fontsize = 16)
show()

# %% [markdown]
# 2.
# =
# Consider a particle in a one-dimensional box of width
# L
# . The probability of nding the
# particle between
# a
# and
# b
# is given by
#
# \begin{equation}
# P(a,b) = \int_a^b|\psi(x)|^2dx
# \end{equation}
#
# where
# $\psi(x)$
# is the wavefunction. (You may need to look in a modern physics or chemistry
# text to get the wave functions for a particle in a box.)
#
# (a)
# -
# What is the probability of finding the particle between
# L
# /3 and
# L
# /2 for the ground
# state and for the first excited state? Perform the integral using both
# trapz
# and
# quad
# with
# an accuracy of 6 sig figs. How many bins did you need to use for
# trapz?

# %%
L = 1.0
x = arange(0, L, .01)
psiground = sqrt(2/L)*sin(pi*x/L)
psiG2 = psiground**2
psifirst = sqrt(2/L)*sin(2*pi*x/L)
psiF2 = psifirst**2
PG = lambda x: (2/L)*sin(pi*x/L)**2
PF = lambda x: (2/L)*sin(2*pi*x/L)**2    

trapzground = integrate.trapz(psiground[L/3:L/2], x[L/3:L/2], dx=.01)
trapzfirst = integrate.trapz(psifirst[L/3:L/2], x[L/3:L/2], dx=.01)
quadground = integrate.quad(PG, L/3, L/2)
quadfirst = integrate.quad(PF, L/3, L/2)
print 'trapz ground state: ' + str(trapzground)
print 'trapz first state: ' + str(trapzfirst)
print 'quad ground state: ' + str(quadground)
print 'quad first state: ' + str(quadfirst)
# Out:
# trapz ground state: 0.0
# trapz first state: 0.0
# quad ground state: (0.30449889052211465, 3.3806167923046653e-15)
# quad first state: (0.09775055473894274, 1.0852491654105595e-15)

# %% [markdown]
# (b)
# -
# To see if these make sense make a plot of $|\psi(x)|^2$ for $L=1$  .

# %%
subplot(211)
plot(x, psiG2)
title('Ground State')
ylabel('$\psi(x)$', fontsize=16)
xticks([])
subplot(212)
title('First Excited state')
plot(x, psiF2)
xlabel('$x$', fontsize=16)
ylabel('$\psi(x)$', fontsize=16)
show()

# %% [markdown]
# 3.
# =
# In natural units (where all the constants are 1), the wavefunction of the n-th energy level of the one-dimensional quantum harmonic oscillator -i.e., a spinless point particle in a quadratic potential well- is given by
#
# $\psi_n(x) = \dfrac{1}{\sqrt{2^nn!\sqrt{\pi}}}e^{-x^2/2}H_n(x)$
#
# for n = 0,1,2... where $H_n(x)$ is the n-th Hermite polynomial.

# %% [markdown]
# (a)
# -
# Write a user-defined function
# H(n,x)
# that calculates
# H
# n
# (
# x
# ) for given
# x
# and any integer
# n
# 0. Use your function to make a plot that shows the wave functions for
# n
# =0, 1, 2,
# and 3, all on the same graph, in the range
# x
# = -4 to
# x
# = 4. Hint: There is a function
# factorial
# in the
# math
# package that calculates the factorial of an integer.

# %%
def H(n,x):
    if n == 0:
        h = 1
    elif n == 1:
        h = 2*x
    elif n == 2:
        h = 2*x*(2*x)-2*(n-1)
    else:
        H0 = 1
        H1 = 2*x
        HN = 2*x*H1-2*H0
        for i in range(2,n):
            h = 2*x*HN-2*i*H1
            H1 = HN
            HN = h
    return h

# %%
from math import factorial
x = arange(-4, 4, .01)
labels = ['n=0', 'n=1', 'n=2', 'n=3']
for n in range(0,4):
    psi = 1/(sqrt(2**n * factorial(n)* sqrt(pi))) * e**(-x**2 / 2) * H(n,x)
    plot(x, psi, label=labels[n])
legend()
title('Harmonic Oscillator wavefunctions for n=0 through n=3', fontsize = 16)
xlabel('x', fontsize=16)
ylabel('$\psi(x)$', fontsize=16)
show()

# %% [markdown]
# (b)
# -
# Make a separate plot of the wave function for
# $n
# = 30$  from
# $x
# = -10$  to
# $x
# = 10$.  If your
# code takes too long to run, then you are doing the calculation wrong - it should only take
# a second or so to run.

# %%
x = arange(-10.0,10.0,.01)
n = 30
psi = 1/(sqrt(2**n * float(factorial(n))* sqrt(pi))) * e**(-x**2 / 2) * H(n,x)
plot(x, psi)
title('Harmonic Oscillator wavefunction, n=30', fontsize = 16)
xlabel('x', fontsize=16)
ylabel('$\psi(x)$', fontsize=18)
show()

# %% [markdown]
# (c)
# -
# Write code that evaluates this integral and calculates the uncertainty for a given value of n. Calculate the uncertainty for n = 5. You should get an answer in the vicinty of 2.3.

# %%
n = 5
psi = 1/(sqrt(2**n * factorial(n) * sqrt(pi))) * e**(-x**2 / 2) * H(n,x)
y = (x**2) * (psi**2)
uncertainty = sqrt(integrate.trapz(y, x, dx=.1))
print uncertainty
# Out:
# 2.34520787991

# %% [markdown]
# 4
# =
# (a)
# -

# %% [markdown]
# Use the hit or miss Monte Carlo method to estimate the integral of $f(x) = 4\sqrt{1-x^2}$
#
# from 0 to 1 as a function of N, the number of samples.

# %%
f = lambda x: 4*sqrt(1-x**2)
x = arange(0.,15.,.001)
xmin = 0.
xmax = 1.2

subx = x[logical_and((x > xmin), (x < xmax))]
ymax = max(f(subx))*1.05
ymin = 0.
myplot = plot(x,f(x),lw=3)
xlim(0.,1.5)

plot([xmax,xmax],[ymin,ymax],c='k', ls='--')
plot([xmin,xmax],[ymax,ymax],c='k', ls='--')
xlabel('$x$', fontsize=16)
ylabel('$4\sqrt{1-x^2}$', fontsize=16)
show()

# %%
N = 1000000
samples_x = xmin + (xmax-xmin)*random_sample(N)
samples_y = ymin + (ymax-ymin)*random_sample(N)
newmask = (samples_y < f(samples_x))
I = (xmax-xmin)*(ymax-ymin)*sum(newmask)/newmask.size
print I
# Out:
# 3.14185378907

# %% [markdown]
# (b)
# -
# Calculate the difference between your result from part (a) and the exact result $\pi$ for the N values from part (a).

# %%
error = abs(pi - I)
print error
# Out:
# 0.000261135482134

# %% [markdown]
# (c)
# -

# %% [markdown]
# (d)
# -

# %% [markdown]
# 5.
# =
#
# $M = \int\rho dV$
#
# $r_{cm} = \int r \rho dV$
#
# $I_cm = \int (r-r_{cm})^2 \rho dV$
#
# Consider a rectangular box: L=.2m, W= .2m, H= 1.0m centered on the origin, with $\rho(x,y)$ = 100kg/m[(y+.1)+$z^2$] for y and z in meters.

# %% [markdown]
# (a)
# -
# Use numerical integration to find $M, r_{cm},$  and $I_cm$.

# %%
l = 0.2
w = 0.2
h = 1.0
rho = lambda z,y: 100*((y +0.1) +z**2)

# %%
M = integrate.tplquad(rho, -l, l, lambda x: -.1, lambda x: .1, lambda x: -.5, lambda x: .5)
print 'M: ' + str(M[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-120-1d5f06a600d3> in <module>()
# ----> 1 M = integrate.tplquad(rho, -l, l, lambda x: -.1, lambda x: .1, lambda x: -.5, lambda x: .5)
#       2 print 'M: ' + str(M[0])
#
# /home/ssteeper/Downloads/epd-7.2-2-rh5-x86/lib/python2.7/site-packages/scipy/integrate/quadpack.py in tplquad(func, a, b, gfun, hfun, qfun, rfun, args, epsabs, epsrel)
#     484
#     485     """
# --> 486     return dblquad(_infunc2,a,b,gfun,hfun,(func,qfun,rfun,args),epsabs=epsabs,epsrel=epsrel)
#
# /home/ssteeper/Downloads/epd-7.2-2-rh5-x86/lib/python2.7/site-packages/scipy/integrate/quadpack.py in dblquad(func, a, b, gfun, hfun, args, epsabs, epsrel)
#     421
#     422     """
# --> 423     return quad(_infunc,a,b,(func,gfun,hfun,args),epsabs=epsabs,epsrel=epsrel)
#     424
#     425 def _infunc2(y,x,func,qfun,rfun,more_args):
#
# ...

# %% [markdown]
# (b)
# -
# Think of a way to test the algorithm using a constant density. Verify that this gives reasonable results.

# %%
rho = lambda x: 1.0
